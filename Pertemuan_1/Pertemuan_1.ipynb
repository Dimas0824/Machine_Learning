# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimas0824/Machine_Learning/blob/main/Pertemuan_1/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 41.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# lakukan konfigurasi di Komputer Lokal

# %%
from IPython.display import Image, display

# Tampilkan screenshoot
display(Image(filename='/content/drive/MyDrive/Machine Learning/Jobsheet 1/img/ScreenShootInstall.png'))
